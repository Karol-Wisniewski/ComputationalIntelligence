# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.read_csv("diabetes.csv")
(train_set, test_set) = train_test_split(df.values, train_size=0.7,
random_state=2723743473)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf.fit(train_set[:, :-1], train_set[:, -1])
# Out:
# DecisionTreeClassifier()

# %%
print(tree.export_text(clf, feature_names=list(df.columns.values[:-1])))
# Out:
# |--- glucose-concentr <= 127.50
# |   |--- age <= 27.50
# |   |   |--- mass-index <= 30.95
# |   |   |   |--- pregnant-times <= 7.50
# |   |   |   |   |--- pedigree-func <= 0.67
# |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |--- pedigree-func >  0.67
# |   |   |   |   |   |--- mass-index <= 24.00
# |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |--- mass-index >  24.00
# |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |--- pregnant-times >  7.50
# |   |   |   |   |--- class: tested_positive
# |   |   |--- mass-index >  30.95
# |   |   |   |--- mass-index <= 45.35
# |   |   |   |   |--- pedigree-func <= 0.50
# |   |   |   |   |   |--- mass-index <= 31.30
# |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |--- mass-index >  31.30
# |   |   |   |   |   |   |--- skin-thickness <= 8.50
# |   |   |   |   |   |   |   |--- glucose-concentr <= 109.50
# |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |--- glucose-concentr >  109.50
# |   |   |   |   |   |   |   |   |--- mass-index <= 32.45
# |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |   |--- mass-index >  32.45
# |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |--- skin-thickness >  8.50
# |   |   |   |   |   |   |   |--- mass-index <= 31.80
# |   |   |   |   |   |   |   |   |--- glucose-concentr <= 102.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |   |--- glucose-concentr >  102.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |--- mass-index >  31.80
# |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |--- pedigree-func >  0.50
# |   |   |   |   |   |--- pedigree-func <= 0.54
# |   |   |   |   |   |   |--- blood-pressure <= 61.00
# |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |--- blood-pressure >  61.00
# |   |   |   |   |   |   |   |--- insulin <= 152.50
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |--- insulin >  152.50
# |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |--- pedigree-func >  0.54
# |   |   |   |   |   |   |--- skin-thickness <= 42.50
# |   |   |   |   |   |   |   |--- pedigree-func <= 1.27
# |   |   |   |   |   |   |   |   |--- mass-index <= 42.80
# |   |   |   |   |   |   |   |   |   |--- insulin <= 154.00
# |   |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |   |   |--- insulin >  154.00
# |   |   |   |   |   |   |   |   |   |   |--- pedigree-func <= 0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |   |   |   |--- pedigree-func >  0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |   |--- mass-index >  42.80
# |   |   |   |   |   |   |   |   |   |--- blood-pressure <= 75.00
# |   |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |   |   |--- blood-pressure >  75.00
# |   |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |--- pedigree-func >  1.27
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |--- skin-thickness >  42.50
# |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |--- mass-index >  45.35
# |   |   |   |   |--- blood-pressure <= 93.00
# |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |--- blood-pressure >  93.00
# |   |   |   |   |   |--- class: tested_negative
# |   |--- age >  27.50
# |   |   |--- glucose-concentr <= 99.50
# |   |   |   |--- pedigree-func <= 1.16
# |   |   |   |   |--- glucose-concentr <= 28.50
# |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |--- glucose-concentr >  28.50
# |   |   |   |   |   |--- glucose-concentr <= 94.50
# |   |   |   |   |   |   |--- pregnant-times <= 11.50
# |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |--- pregnant-times >  11.50
# |   |   |   |   |   |   |   |--- mass-index <= 31.25
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |--- mass-index >  31.25
# |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |--- glucose-concentr >  94.50
# |   |   |   |   |   |   |--- blood-pressure <= 75.00
# |   |   |   |   |   |   |   |--- skin-thickness <= 8.50
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |--- skin-thickness >  8.50
# |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |--- blood-pressure >  75.00
# |   |   |   |   |   |   |   |--- glucose-concentr <= 98.00
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |--- glucose-concentr >  98.00
# |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |--- pedigree-func >  1.16
# |   |   |   |   |--- class: tested_positive
# |   |   |--- glucose-concentr >  99.50
# |   |   |   |--- mass-index <= 43.10
# |   |   |   |   |--- mass-index <= 26.25
# |   |   |   |   |   |--- mass-index <= 9.80
# |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |--- mass-index >  9.80
# |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |--- mass-index >  26.25
# |   |   |   |   |   |--- blood-pressure <= 84.00
# |   |   |   |   |   |   |--- pedigree-func <= 0.20
# |   |   |   |   |   |   |   |--- glucose-concentr <= 120.00
# |   |   |   |   |   |   |   |   |--- blood-pressure <= 79.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |   |--- blood-pressure >  79.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |--- glucose-concentr >  120.00
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |--- pedigree-func >  0.20
# |   |   |   |   |   |   |   |--- pregnant-times <= 5.50
# |   |   |   |   |   |   |   |   |--- glucose-concentr <= 123.50
# |   |   |   |   |   |   |   |   |   |--- pedigree-func <= 0.39
# |   |   |   |   |   |   |   |   |   |   |--- skin-thickness <= 21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |   |   |   |--- skin-thickness >  21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |   |   |--- pedigree-func >  0.39
# |   |   |   |   |   |   |   |   |   |   |--- pedigree-func <= 0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |   |   |   |--- pedigree-func >  0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- glucose-concentr >  123.50
# |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |--- pregnant-times >  5.50
# |   |   |   |   |   |   |   |   |--- age <= 53.50
# |   |   |   |   |   |   |   |   |   |--- pedigree-func <= 0.54
# |   |   |   |   |   |   |   |   |   |   |--- pedigree-func <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- pedigree-func >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- pedigree-func >  0.54
# |   |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |   |--- age >  53.50
# |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |--- blood-pressure >  84.00
# |   |   |   |   |   |   |--- pedigree-func <= 0.79
# |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |--- pedigree-func >  0.79
# |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |--- mass-index >  43.10
# |   |   |   |   |--- class: tested_positive
# |--- glucose-concentr >  127.50
# |   |--- glucose-concentr <= 154.50
# |   |   |--- pedigree-func <= 0.29
# |   |   |   |--- age <= 27.50
# |   |   |   |   |--- class: tested_negative
# |   |   |   |--- age >  27.50
# |   |   |   |   |--- blood-pressure <= 73.00
# |   |   |   |   |   |--- pregnant-times <= 5.00
# |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |--- pregnant-times >  5.00
# |   |   |   |   |   |   |--- pedigree-func <= 0.26
# |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |--- pedigree-func >  0.26
# |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |--- blood-pressure >  73.00
# |   |   |   |   |   |--- blood-pressure <= 91.00
# |   |   |   |   |   |   |--- skin-thickness <= 32.50
# |   |   |   |   |   |   |   |--- glucose-concentr <= 146.00
# |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |--- glucose-concentr >  146.00
# |   |   |   |   |   |   |   |   |--- blood-pressure <= 79.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |   |--- blood-pressure >  79.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |--- skin-thickness >  32.50
# |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |--- blood-pressure >  91.00
# |   |   |   |   |   |   |--- class: tested_positive
# |   |   |--- pedigree-func >  0.29
# |   |   |   |--- glucose-concentr <= 152.50
# |   |   |   |   |--- age <= 30.00
# |   |   |   |   |   |--- blood-pressure <= 56.00
# |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |--- blood-pressure >  56.00
# |   |   |   |   |   |   |--- mass-index <= 41.70
# |   |   |   |   |   |   |   |--- pedigree-func <= 1.04
# |   |   |   |   |   |   |   |   |--- pedigree-func <= 0.57
# |   |   |   |   |   |   |   |   |   |--- pedigree-func <= 0.54
# |   |   |   |   |   |   |   |   |   |   |--- glucose-concentr <= 137.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |   |   |   |--- glucose-concentr >  137.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- pedigree-func >  0.54
# |   |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |   |--- pedigree-func >  0.57
# |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |--- pedigree-func >  1.04
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |--- mass-index >  41.70
# |   |   |   |   |   |   |   |--- pedigree-func <= 0.86
# |   |   |   |   |   |   |   |   |--- skin-thickness <= 50.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |   |--- skin-thickness >  50.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |--- pedigree-func >  0.86
# |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |--- age >  30.00
# |   |   |   |   |   |--- mass-index <= 28.20
# |   |   |   |   |   |   |--- glucose-concentr <= 145.50
# |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |--- glucose-concentr >  145.50
# |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |--- mass-index >  28.20
# |   |   |   |   |   |   |--- pedigree-func <= 0.43
# |   |   |   |   |   |   |   |--- insulin <= 39.50
# |   |   |   |   |   |   |   |   |--- skin-thickness <= 41.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |   |--- skin-thickness >  41.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |--- insulin >  39.50
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |--- pedigree-func >  0.43
# |   |   |   |   |   |   |   |--- pedigree-func <= 1.55
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |--- pedigree-func >  1.55
# |   |   |   |   |   |   |   |   |--- age <= 38.50
# |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |   |--- age >  38.50
# |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |--- glucose-concentr >  152.50
# |   |   |   |   |--- class: tested_negative
# |   |--- glucose-concentr >  154.50
# |   |   |--- insulin <= 629.50
# |   |   |   |--- age <= 62.50
# |   |   |   |   |--- pedigree-func <= 0.34
# |   |   |   |   |   |--- pedigree-func <= 0.27
# |   |   |   |   |   |   |--- pregnant-times <= 9.50
# |   |   |   |   |   |   |   |--- mass-index <= 39.05
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |--- mass-index >  39.05
# |   |   |   |   |   |   |   |   |--- insulin <= 220.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |   |   |--- insulin >  220.00
# |   |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |--- pregnant-times >  9.50
# |   |   |   |   |   |   |   |--- pregnant-times <= 11.50
# |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |--- pregnant-times >  11.50
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |--- pedigree-func >  0.27
# |   |   |   |   |   |   |--- mass-index <= 34.05
# |   |   |   |   |   |   |   |--- pregnant-times <= 8.00
# |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |--- pregnant-times >  8.00
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |--- mass-index >  34.05
# |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |--- pedigree-func >  0.34
# |   |   |   |   |   |--- blood-pressure <= 100.00
# |   |   |   |   |   |   |--- insulin <= 520.00
# |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |   |--- insulin >  520.00
# |   |   |   |   |   |   |   |--- insulin <= 562.00
# |   |   |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |   |   |   |--- insulin >  562.00
# |   |   |   |   |   |   |   |   |--- class: tested_positive
# |   |   |   |   |   |--- blood-pressure >  100.00
# |   |   |   |   |   |   |--- class: tested_negative
# |   |   |   |--- age >  62.50
# |   |   |   |   |--- blood-pressure <= 85.00
# |   |   |   |   |   |--- class: tested_negative
# |   |   |   |   |--- blood-pressure >  85.00
# |   |   |   |   |   |--- class: tested_positive
# |   |   |--- insulin >  629.50
# |   |   |   |--- class: tested_negative

# %%
def benchmark(clf, test_set):
	predictions = clf.predict(test_set[:, :-1])
	return sum(predictions == test_set[:, -1]) / len(test_set)

# %%
benchmark(clf, test_set)
# Out:
# 0.7402597402597403

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(test_set[:, -1], clf.predict(test_set[:, :-1])))
print(classification_report(test_set[:, -1], clf.predict(test_set[:, :-1])))
# Out:
# [[119  36]
#  [ 24  52]]
#                  precision    recall  f1-score   support
#
# tested_negative       0.83      0.77      0.80       155
# tested_positive       0.59      0.68      0.63        76
#
#        accuracy                           0.74       231
#       macro avg       0.71      0.73      0.72       231
#    weighted avg       0.75      0.74      0.74       231
