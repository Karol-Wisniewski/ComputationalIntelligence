# %%
import pyswarms as ps
import math
import numpy as np
from pyswarms.utils.plotters import plot_cost_history
import matplotlib.pyplot as plt

# %%
def endurance(x):
    x1, x2, x3, x4, x5, x6 = x
    return math.exp(-2 * (x2 - math.sin(x1)) ** 2) + math.sin(x3 * x4) + math.cos(x5 * x6)

# %%
def f(x):
    n_particles = x.shape[0]
    j = [-endurance(x[i]) for i in range(n_particles)]
    return np.array(j)

# %%
x_max = np.ones(6)
x_min = np.zeros(6)
my_bounds = (x_min, x_max)
options = {'c1': 0.5, 'c2': 0.3, 'w':0.9}

optimizer = ps.single.GlobalBestPSO(n_particles=10, dimensions=6,
options=options, bounds=my_bounds)
optimizer.optimize(f, iters=1000)
# Out:
# 2023-03-28 22:41:44,528 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=-2.81
# 2023-03-28 22:41:46,462 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -2.8097224329088113, best pos: [0.57009507 0.55735665 0.96598038 0.9937371  0.39564599 0.33568909]
# (-2.8097224329088113,
#  array([0.57009507, 0.55735665, 0.96598038, 0.9937371 , 0.39564599,
#         0.33568909]))

# %%
cost_history = optimizer.cost_history
plot_cost_history(cost_history)
plt.show()
